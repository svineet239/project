# %%
import pandas as pd

# %%
data =pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset4/main/medical_cost_insurance.csv")
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.mean()
# Out:
# C:\Users\utkar\AppData\Local\Temp\ipykernel_32308\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# age            39.207025
# bmi            30.663397
# children        1.094918
# charges     13270.422265
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\utkar\AppData\Local\Temp\ipykernel_32308\4184645713.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# age           39.000
# bmi           30.400
# children       1.000
# charges     9382.033
# dtype: float64

# %%
data.std()
# Out:
# C:\Users\utkar\AppData\Local\Temp\ipykernel_32308\2723740006.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# age            14.049960
# bmi             6.098187
# children        1.205493
# charges     12110.011237
# dtype: float64

# %%
data.shape
# Out:
# (1338, 7)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.corr()
# Out:
# C:\Users\utkar\AppData\Local\Temp\ipykernel_32308\1185648202.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# C:\Users\utkar\AppData\Local\Temp\ipykernel_32308\1119197534.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True)
# <Axes: >

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.pairplot(data)

# %%
data.value_counts
# Out:
# <bound method DataFrame.value_counts of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
plt.figure (figsize = (25,10))
plt.subplot(2,2,1)
sns.boxplot(x = 'region', y = 'charges', data = data)

plt.subplot(2,2,2)
sns.boxplot(x = 'children', y = 'charges', data = data)

plt.subplot(2,2,3)
sns.boxplot(x = 'sex', y = 'charges', data = data)

plt.subplot(2,2,4)
sns.boxplot(x = 'smoker', y = 'charges', data = data)
# Out:
# <Axes: xlabel='smoker', ylabel='charges'>

# %%
charges = data['charges'].groupby(data.age).sum().sort_values(ascending = True)
plt.figure(figsize=(20,5))
ax = sns.barplot(x = charges.index, y = charges)

# %%
charges = data['charges'].groupby(data.sex).sum().sort_values(ascending = True)
plt.figure(figsize=(20,5))
ax = sns.barplot(x = charges.index, y = charges)

# %%
charges = data['charges'].groupby(data.bmi).sum().sort_values(ascending = True)
plt.figure(figsize=(20,5))
ax = sns.barplot(x = charges.index, y = charges)

# %%
plt.figure(figsize=(15,5))
ax = sns.barplot(x = 'region', y = 'charges', hue = 'age', data = data)

# %%
plt.figure(figsize=(15,5))
ax = sns.barplot(x = 'region', y = 'charges', hue = 'smoker', data = data)

# %%
ax = sns.lmplot(x = 'age', y = 'charges', data = data, hue = 'smoker', palette = 'Set3')
plt.title('Age vs Medical Charges')

ax = sns.lmplot(x = 'bmi', y = 'charges', data = data, hue = 'sex', palette = 'Set1')
plt.title('BMI vs Medical Charges')

ax = sns.lmplot(x = 'children', y = 'charges', data = data, hue = 'smoker', palette = 'Set2')
plt.title('Number of children vs Medical Charges')
# Out:
# Text(0.5, 1.0, 'Number of children vs Medical Charges')

# %%
sns.lmplot(x='children', y='charges', hue='smoker',data= data,fit_reg=False,palette="magma")
fig=plt.gcf()
fig.set_size_inches(20,8)
plt.title("Plot for Charges & children", weight='bold')
# Out:
# Text(0.5, 1.0, 'Plot for Charges & children')

# %%
# Converting data to categorical type data
data[['region','sex','smoker']] = data[['region','sex','smoker']].astype('category')
data.dtypes

# %%
# Converting Data to numerical type using LabelEncoder
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

label.fit(data.region.drop_duplicates())
data.region = label.transform(data.region)

label.fit(data.sex.drop_duplicates())
data.sex = label.transform(data.sex)

label.fit(data.smoker.drop_duplicates())
data.smoker = label.transform(data.smoker)

data.dtypes
# Out:
# age           int64
# sex           int32
# bmi         float64
# children      int64
# smoker        int32
# region        int32
# charges     float64
# dtype: object

# %%
sns.pairplot(data)

# %%
X = data.drop(columns='charges',axis=1)
Y  = data['charges']

# %%
X
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1338 rows x 6 columns]

# %%
Y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1338, 6) (1070, 6) (268, 6)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
training_data_pred = regressor.predict(X_train)
r2_train = metrics.r2_score(Y_train,training_data_pred)
print('R2 train:',r2_train)
# Out:
# R2 train: 0.7519923667088932

# %%
test_data_pred = regressor.predict(X_test)
r2_test = metrics.r2_score(Y_test,test_data_pred)
print('R2 test:',r2_test)
# Out:
# R2 test: 0.7445422986536503

# %%
rmse_linear = (np.sqrt(mean_squared_error(Y_test, test_data_pred)))
print('RMSE : {0:.3f}'.format(rmse_linear))
# Out:
# RMSE : 6193.935
